# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_2019 = pd.read_csv('traffic_2019_with_car_nums.csv', parse_dates=['timestamp'], index_col = 1)
df_2019
# Out:
#                            Unnamed: 0  \
# timestamp
# 2018-12-31 23:59:44+08:00           0
# 2019-01-01 00:00:44+08:00           1
# 2019-01-01 00:01:25+08:00           2
# 2019-01-01 00:03:45+08:00           3
# 2019-01-01 00:05:25+08:00           4
# ...                               ...
# 2019-01-31 23:54:47+08:00       30205
# 2019-01-31 23:56:27+08:00       30206
# 2019-01-31 23:57:27+08:00       30207
# 2019-01-31 23:58:27+08:00       30208
# 2019-01-31 23:59:47+08:00       30209
#
#                                                                        image  \
# timestamp
# 2018-12-31 23:59:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:01:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:03:45+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:05:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...

# %%
df_2019.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30210 entries, 2018-12-31 23:59:44+08:00 to 2019-01-31 23:59:47+08:00
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image                  30210 non-null  object
#  1   camera_id              30210 non-null  int64
#  2   location.latitude      30210 non-null  float64
#  3   location.longitude     30210 non-null  float64
#  4   image_metadata.height  30210 non-null  int64
#  5   image_metadata.width   30210 non-null  int64
#  6   image_metadata.md5     30210 non-null  object
#  7   num_cars               30210 non-null  int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 2.1+ MB

# %%
df_2020 = pd.read_csv('traffic_2020_with_car_nums.csv', parse_dates=['timestamp'], index_col = 1)
df_2020
# Out:
#                            Unnamed: 0  \
# timestamp
# 2019-12-31 23:59:24+08:00           0
# 2020-01-01 00:00:44+08:00           1
# 2020-01-01 00:01:44+08:00           2
# 2020-01-01 00:02:44+08:00           3
# 2020-01-01 00:03:24+08:00           4
# ...                               ...
# 2020-01-31 23:53:30+08:00       29932
# 2020-01-31 23:54:50+08:00       29933
# 2020-01-31 23:56:30+08:00       29934
# 2020-01-31 23:57:30+08:00       29935
# 2020-01-31 23:59:10+08:00       29936
#
#                                                                        image  \
# timestamp
# 2019-12-31 23:59:24+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:01:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:02:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:03:24+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...

# %%
df_2020.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29937 entries, 2019-12-31 23:59:24+08:00 to 2020-01-31 23:59:10+08:00
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image                  29937 non-null  object
#  1   camera_id              29937 non-null  int64
#  2   location.latitude      29937 non-null  float64
#  3   location.longitude     29937 non-null  float64
#  4   image_metadata.height  29937 non-null  int64
#  5   image_metadata.width   29937 non-null  int64
#  6   image_metadata.md5     29937 non-null  object
#  7   num_cars               29937 non-null  int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 2.1+ MB

# %%
sns.histplot(data=df_2019, x='num_cars')
plt.title('Number of cars 2019')
plt.show()

# %%
sns.histplot(data=df_2020, x='num_cars')
plt.title('Number of cars 2020')
plt.show()

# %%
sns.histplot(data=df_2019, x='num_cars', color = 'blue', alpha=0.5, kde=True)
sns.histplot(data=df_2020, x='num_cars', color = 'green', alpha=0.5, kde=True)
plt.title('Number of cars for both years')
plt.show()

# %%
plt.hist([df_2019['num_cars'], df_2020['num_cars']], color=['r', 'b'], alpha=0.5, log=True)
plt.title('Log-scaled number of cars for both years')
plt.show()

# %%
resampled_by_day_2019 = df_2019.resample('D')['num_cars'].sum()
resampled_by_day_2019
# Out:
# timestamp
# 2018-12-31 00:00:00+08:00       6
# 2019-01-01 00:00:00+08:00    5481
# 2019-01-02 00:00:00+08:00    5978
# 2019-01-03 00:00:00+08:00    6839
# 2019-01-04 00:00:00+08:00    6940
# 2019-01-05 00:00:00+08:00    6915
# 2019-01-06 00:00:00+08:00    6316
# 2019-01-07 00:00:00+08:00    6942
# 2019-01-08 00:00:00+08:00    6836
# 2019-01-09 00:00:00+08:00    6904
# 2019-01-10 00:00:00+08:00    7227
# 2019-01-11 00:00:00+08:00    7214
# 2019-01-12 00:00:00+08:00    7104
# 2019-01-13 00:00:00+08:00    7005
# 2019-01-14 00:00:00+08:00    3369
# 2019-01-15 00:00:00+08:00     676
# 2019-01-16 00:00:00+08:00     462
# 2019-01-17 00:00:00+08:00       0
# 2019-01-18 00:00:00+08:00     259
# 2019-01-19 00:00:00+08:00       0
# 2019-01-20 00:00:00+08:00       0
# 2019-01-21 00:00:00+08:00       0
# 2019-01-22 00:00:00+08:00       0
# 2019-01-23 00:00:00+08:00       0
# 2019-01-24 00:00:00+08:00     544
# 2019-01-25 00:00:00+08:00    1807
# 2019-01-26 00:00:00+08:00       0
# ...

# %%
resampled_by_day_2020 = df_2020.resample('D')['num_cars'].sum()
resampled_by_day_2020
# Out:
# timestamp
# 2019-12-31 00:00:00+08:00       2
# 2020-01-01 00:00:00+08:00    6374
# 2020-01-02 00:00:00+08:00    6691
# 2020-01-03 00:00:00+08:00    7351
# 2020-01-04 00:00:00+08:00    7294
# 2020-01-05 00:00:00+08:00    6462
# 2020-01-06 00:00:00+08:00    7232
# 2020-01-07 00:00:00+08:00    6968
# 2020-01-08 00:00:00+08:00    7209
# 2020-01-09 00:00:00+08:00    7665
# 2020-01-10 00:00:00+08:00    7366
# 2020-01-11 00:00:00+08:00    7659
# 2020-01-12 00:00:00+08:00    7006
# 2020-01-13 00:00:00+08:00    7456
# 2020-01-14 00:00:00+08:00    7522
# 2020-01-15 00:00:00+08:00     312
# 2020-01-16 00:00:00+08:00       0
# 2020-01-17 00:00:00+08:00       0
# 2020-01-18 00:00:00+08:00    1094
# 2020-01-19 00:00:00+08:00       0
# 2020-01-20 00:00:00+08:00       0
# 2020-01-21 00:00:00+08:00       0
# 2020-01-22 00:00:00+08:00     306
# 2020-01-23 00:00:00+08:00       0
# 2020-01-24 00:00:00+08:00     105
# 2020-01-25 00:00:00+08:00     272
# 2020-01-26 00:00:00+08:00       0
# ...

# %%
plt.plot(resampled_by_day_2020.values[1:], label='2020')
plt.plot(resampled_by_day_2019.values[1:], label='2019')
plt.title('Numbers of cars per day for both years')
plt.legend()
plt.show()

# %%
df_2019['day_of_week'] = df_2019.index.dayofweek
df_2019
# Out:
#                                                                        image  \
# timestamp
# 2018-12-31 23:59:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:01:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:03:45+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:05:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...                                                                      ...
# 2019-01-31 23:54:47+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:56:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:57:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:58:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:59:47+08:00  https://images.data.gov.sg/api/traffic-images/...
#
# ...

# %%
df_2020['day_of_week'] = df_2020.index.dayofweek
df_2020
# Out:
#                                                                        image  \
# timestamp
# 2019-12-31 23:59:24+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:01:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:02:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:03:24+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...                                                                      ...
# 2020-01-31 23:53:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:54:50+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:56:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:57:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:59:10+08:00  https://images.data.gov.sg/api/traffic-images/...
#
# ...

# %%
df_2019.drop(index=df_2019.index[0],
            axis=0,
            inplace=True)
df_2019
# Out:
#                                                                        image  \
# timestamp
# 2019-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:01:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:03:45+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:05:25+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-01 00:06:45+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...                                                                      ...
# 2019-01-31 23:54:47+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:56:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:57:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:58:27+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2019-01-31 23:59:47+08:00  https://images.data.gov.sg/api/traffic-images/...
#
# ...

# %%
df_2020.drop(index=df_2020.index[0],
            axis=0,
            inplace=True)
df_2020
# Out:
#                                                                        image  \
# timestamp
# 2020-01-01 00:00:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:01:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:02:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:03:24+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-01 00:04:44+08:00  https://images.data.gov.sg/api/traffic-images/...
# ...                                                                      ...
# 2020-01-31 23:53:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:54:50+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:56:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:57:30+08:00  https://images.data.gov.sg/api/traffic-images/...
# 2020-01-31 23:59:10+08:00  https://images.data.gov.sg/api/traffic-images/...
#
# ...

# %%
groupby_2019 = df_2019.groupby(by=['day_of_week'])['num_cars'].mean()
groupby_2019
# Out:
# day_of_week
# 0    2.632372
# 1    2.672907
# 2    2.719935
# 3    2.985288
# 4    4.215177
# 5    3.621545
# 6    3.405164
# Name: num_cars, dtype: float64

# %%
groupby_2020 = df_2020.groupby(by=['day_of_week'])['num_cars'].mean()
groupby_2020
# Out:
# day_of_week
# 0    3.758444
# 1    3.752914
# 2    2.969889
# 3    2.991457
# 4    3.136931
# 5    4.234302
# 6    3.447146
# Name: num_cars, dtype: float64

# %%
plt.plot(groupby_2019, label='2019')
plt.plot(groupby_2020, label='2020')
plt.legend()
plt.title('Average traffic per day of the week')
plt.xlabel('Day of the week')
plt.ylabel('Avg cars')
plt.show()

# %%
groupby_2019 = df_2019[df_2019['num_cars'] > 0].groupby(by=['day_of_week'])['num_cars'].mean()
groupby_2019
# Out:
# day_of_week
# 0    7.592784
# 1    7.162624
# 2    7.625143
# 3    7.637219
# 4    8.395445
# 5    7.660656
# 6    7.188883
# Name: num_cars, dtype: float64

# %%
groupby_2020 = df_2020[df_2020['num_cars'] > 0].groupby(by=['day_of_week'])['num_cars'].mean()
groupby_2020
# Out:
# day_of_week
# 0    7.858748
# 1    7.918033
# 2    6.868309
# 3    7.772604
# 4    8.139484
# 5    8.094742
# 6    7.095890
# Name: num_cars, dtype: float64

# %%
plt.plot(groupby_2019, label='2019')
plt.plot(groupby_2020, label='2020')
plt.legend()
plt.title('Average traffic per day of the week')
plt.xlabel('Day of the week')
plt.ylabel('Avg cars')
plt.show()

# %%
from scipy import stats

# %%
stats.ttest_ind(df_2019['num_cars'], df_2020['num_cars'])
# Out:
# Ttest_indResult(statistic=-7.57760235507139, pvalue=3.5702258720051755e-14)

# %% [markdown]
# There doesn't seem to be a significant difference between trafic in 2019/2020.
